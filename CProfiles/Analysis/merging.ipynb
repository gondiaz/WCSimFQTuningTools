# %%
import os
import re
import uproot
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib widget
from matplotlib.colors import LogNorm

# %% [markdown]
# ### Merging

# %%
fname  = os.path.expandvars("$T2K_LUSTRE/CProfiles/e-/tuning/cprofiles_merged.root")
f  = uproot.open(fname)
print(f.classnames())

# get momentum values
momenta = np.sort([float(re.findall(r'\d+(?:\.\d+)?', key)[0]) for key in f.keys() if re.match("g_\d+", key)])
# Out:
# {'g_225.0;1': 'TH2D', 'g_100.0;1': 'TH2D', 'g_125.0;1': 'TH2D', 'g_175.0;1': 'TH2D', 'g_200.0;1': 'TH2D', 'g_150.0;1': 'TH2D', 'g_250.0;1': 'TH2D', 'g_300.0;1': 'TH2D', 'g_275.0;1': 'TH2D', 'g_325.0;1': 'TH2D', 'g_350.0;1': 'TH2D', 'g_375.0;1': 'TH2D', 'g_425.0;1': 'TH2D', 'g_400.0;1': 'TH2D', 'g_600.0;1': 'TH2D', 'g_525.0;1': 'TH2D', 'g_450.0;1': 'TH2D', 'g_475.0;1': 'TH2D', 'g_550.0;1': 'TH2D', 'g_575.0;1': 'TH2D', 'g_500.0;1': 'TH2D', 'g_nevents;1': 'TGraph'}

# %%
# choose random momentum
# p = 240
# i = np.digitize(p, momenta)
# momentum = momenta[i]
momentum = np.random.choice(momenta)
H, thbins, sbins  =  f[f"g_{momentum}"].to_numpy()

plt.figure(figsize=[5, 3])

plt.title(f"Momentum = {momentum}")
plt.pcolormesh(thbins, sbins, H.T, cmap="jet")
plt.xlim([0.6, 0.9])
plt.ylim([None, 250])
plt.xlabel(r"$\cos \theta$")
plt.ylabel("s [cm]")
plt.colorbar(label="# entries")

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import uproot
fin = uproot.open("/sps/t2k/gdiazlop/CProfiles/e-/out/out_e-_250_586.root")
h, thbins, sbins = fin[f"wtg"].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import uproot
# ----> 2 fin = uproot.open("/sps/t2k/gdiazlop/CProfiles/e-/out/out_e-_250_586.root")
#       3 h, thbins, sbins = fin[f"wtg"].to_numpy()
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/uproot/reading.py:141, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     132 if not isinstance(file_path, str) and not (
#     133     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     134 ):
#     135     raise ValueError(
#     136         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     137         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     138         f"not {path!r}"
#     139     )
# --> 141 file = ReadOnlyFile(
#     142     file_path,
#     143     object_cache=object_cache,
#     144     array_cache=array_cache,
#     145     custom_classes=custom_classes,
#     146     decompression_executor=decompression_executor,
#     147     interpretation_executor=interpretation_executor,
#     148     **options,
#     149 )
#     151 if object_path is None:
#     152     return file.root_directory
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/uproot/reading.py:559, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     554 self.hook_before_create_source()
#     556 source_cls, file_path = uproot._util.file_path_to_source_class(
#     557     file_path, self._options
#     558 )
# --> 559 self._source = source_cls(file_path, **self._options)
#     561 self.hook_before_get_chunks()
#     563 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/uproot/source/fsspec.py:41, in FSSpecSource.__init__(self, file_path, **options)
#      38 self._file = None
#      39 self._fh = None
# ---> 41 self._open()
#      43 self.__enter__()
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/uproot/source/fsspec.py:55, in FSSpecSource._open(self)
#      53 def _open(self):
#      54     self._executor = FSSpecLoopExecutor()
# ---> 55     self._file = self._fs.open(self._file_path)
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/fsspec/spec.py:1295, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1293 else:
#    1294     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1295     f = self._open(
#    1296         path,
#    1297         mode=mode,
#    1298         block_size=block_size,
#    1299         autocommit=ac,
#    1300         cache_options=cache_options,
#    1301         **kwargs,
#    1302     )
#    1303     if compression is not None:
#    1304         from fsspec.compression import compr
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/fsspec/implementations/local.py:180, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     178 if self.auto_mkdir and "w" in mode:
#     179     self.makedirs(self._parent(path), exist_ok=True)
# --> 180 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/fsspec/implementations/local.py:302, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     300 self.compression = get_compression(path, compression)
#     301 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 302 self._open()
#
# File ~/.mamba/envs/hk/lib/python3.10/site-packages/fsspec/implementations/local.py:307, in LocalFileOpener._open(self)
#     305 if self.f is None or self.f.closed:
#     306     if self.autocommit or "w" not in self.mode:
# --> 307         self.f = open(self.path, mode=self.mode)
#     308         if self.compression:
#     309             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/sps/t2k/gdiazlop/CProfiles/e-/out/out_e-_250_586.root'

# %%
plt.figure(figsize=[5, 3])
plt.hist(H[H>0].flatten(), bins=np.linspace(0, 200))
plt.yscale("log")
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
momentum = np.random.choice(momenta)
H, thbins, sbins  =  f[f"g_{momentum}"].to_numpy()

plt.figure(figsize=[5, 3])

plt.title(f"Momentum = {momentum}")
plt.stairs(H.T.sum(axis=0), thbins)
# plt.xlim([0.4, None])
plt.xlabel(r"$\cos \theta$")

plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
